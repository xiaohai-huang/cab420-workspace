# %% [markdown]
# # CAB420 Linear Regression, Example 1: Linear Regression
# Dr Simon Denman (s.denman@qut.edu.au)
#
# ## Overview
# This example explores multiple linear regression, and looks at how we can debug/diagnose models.
#
# Please also be aware that there are a large number of ways to do this in python. The pandas and statsmodels approach here is not the only way, and you are welcome to use other packages as you see fit. For the most part in CAB420, we will be using SKLearn, but the output provided by statsmodels here is a little more nicely presented.
#
# ## Too Long; Didn't Read:
# We can compute a linear regression model in Python using statsmodels. We can also do it using sklearn, and a bunch of other packages, but we're using statsmodels.
# * A linear regression model makes a couple of assumptions, that our predictors are indepedant, and that residuals form a gaussian disribution
# * When analysiing a models performance, we can use a number of tools to consider the importance of individual terms, and the validity of the whole model
# * On an individual term level, the p-value is the most useful, and is the p-value for the null hypothesis that the coefficient is equal to 0.  A low p-value means that you can reject the null hypothesis, i.e. that the term is significant and thus important to the model.
# * If the p-value is high (i.e. the term is not sigificant), there are two main reasons for this.
#   * 1) the predictor term and the response aren't related, and thus one has no bearing on the other, in which case the term probably shouldn't be in the model;
#   * 2) the predictor term is correlated with another predictor, and thus the relationship between that variable and the response is (to some extent) captured twice in the model.
# * In either of the above situations, using correlation can help identify what's going on to improve the model
# * On a whole of model level, the $R^2$ and RMSE are useful values to consider.
#   * The $R^2$ indicates how much of the total variation in the data is captured by the model, with a value of 0 indicating that the model captures nothing, and a value of 1 indicating that the model captures everything. While 1 is ideal performance, an $R^2$ of 1 may also indicate overfitting. **The $R^2$ can only be calculated on the training data.**
#   * The RMSE (root mean squared error) is a measure of prediction error, i.e. how much the model is out by when comapred to the true values. Smaller RMSEs are better. The scale of the RMSE is not fixed, and depends on the data itself. RMSE can also be computed on training, validation and testing sets.
# * Categorical varaibles can also be included in a model, but are captured diffently to regular continuous variables
# * We can add terms that are the products of existing terms (higher order terms) and while this can help improve performance, if we go too far it can lead to overfitting.

# %%
import pandas
import numpy
import matplotlib.pyplot as plt

import statsmodels.api
import statsmodels.formula.api as sm
import scipy.stats as stats
# Out:
# /opt/conda/envs/cab420-env/lib/python3.9/site-packages/statsmodels/compat/pandas.py:61: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex

# %% [markdown]
# ### Data Pre-Processing
#
# We're going to use pandas to read our data. This will load our data into a pandas dataframe, and easy to index and slice as needed.
#
# For those who are uncertain about Pandas and DataFrames, the [documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html) is a good place to start.

# %%
data = pandas.read_csv('./day.csv')
data.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# The data that we're using comes from the Washington DC Bike Share scheme. In particular, we have data from 2011 and 2012, and it captures:
# * The date, and some other data around that such as the season (summer, winter, etc), month, day of the week, if it's a workday
# * The weather, in terms of the temperature, apparent temperature (i.e. the "feels like" temperature), humidity, windspeed and another categorical that captures the overall "weather type" for the day
# * The number of cyclists, broken down into registered and casual users
#
# We're going to try and predict the total number of cyclists given the weather. As a sanity check, let's plot the number of cyclists over time.

# %%
fig = plt.figure(figsize=[10, 6])
ax = fig.add_subplot(1, 1, 1)
ax.plot(data['cnt'])
ax.set_xlabel('Observation')
ax.set_ylabel('Number of Lyrca Enthusiasts')
ax.set_title('Total Cyclists over Time')
# Out:
# Text(0.5, 1.0, 'Total Cyclists over Time')

# %% [markdown]
# We can see a pretty clear shift in usage from one year to the next, with greater usage in the second year. We'll select just data from the first year to make the data a little more consistent.
#
# We'll split our data into two chunks:
# * Our training set will be the first 9 months of the first year
# * Our testing set will be the final 3 months of the first year

# %%
data_train = data.loc[(data['yr'] == 0) & (data['mnth'] < 10)]
data_test = data.loc[(data['yr'] == 0) & (data['mnth'] >= 10)]
print(data_train.shape)
print(data_test.shape)
# Out:
# (273, 16)
# (92, 16)

# %% [markdown]
# For the sake of sanity, we can check the size of those two arrays to make sure that we have the expected amount of data in each.
#
# We'll also check the correlation between our target variable and the predictors. We're going to start with just using our weather values, so we'll focus on those four terms and their correlation with the total number of cyclists.

# %%
fig = plt.figure(figsize=[10, 10])
ax = fig.add_subplot(2, 2, 1)
ax.scatter(data_train['atemp'], data_train['cnt'])
ax.set_xlabel('atemp')
ax.set_ylabel('Number of People in Lyrca')
ax.set_title(str(data_train['cnt'].corr(data_train['atemp'])))

ax = fig.add_subplot(2, 2, 2)
ax.scatter(data_train['temp'], data_train['cnt'])
ax.set_xlabel('temp')
ax.set_ylabel('Number of People in Lyrca')
ax.set_title(str(data_train['cnt'].corr(data_train['temp'])))

ax = fig.add_subplot(2, 2, 3)
ax.scatter(data_train['hum'], data_train['cnt'])
ax.set_xlabel('hum')
ax.set_ylabel('Number of People in Lyrca')
ax.set_title(str(data_train['cnt'].corr(data_train['hum'])))

ax = fig.add_subplot(2, 2, 4)
ax.scatter(data_train['windspeed'], data_train['cnt'])
ax.set_xlabel('windspeed')
ax.set_ylabel('Number of People in Lyrca')
ax.set_title(str(data_train['cnt'].corr(data_train['windspeed'])))
# Out:
# Text(0.5, 1.0, '-0.28491218365022575')

# %% [markdown]
# There seems to be a relationship between each of our variables and our target. Though it's much stronger for the two temperature variables. One thing to note is that there is also a relationship between some of our variables, in particular atemp and temp.

# %%
fig = plt.figure(figsize=[8, 8])
ax = fig.add_subplot(1, 1, 1)
ax.scatter(data_train['atemp'], data_train['temp'])
ax.set_xlabel('atemp')
ax.set_ylabel('temp')
ax.set_title(str(data_train['atemp'].corr(data_train['temp'])))
# Out:
# Text(0.5, 1.0, '0.9968816302544')

# %% [markdown]
# From the scatter plot, we can see that these two variables are very highly correlated. This will be a problem, which we'll see in a little while.
#
# ## A Simple Model
# On to our model fitting now. We can specify this in a number of ways, but for visual clarity we'll use a formula based on the variable names in the dataframe.
#
# What we're asking here is for the model to esimate `cnt` using the combination of `atemp`, `temp`, `hum` and `windspeed`.

# %%
model = sm.ols(formula="cnt ~ atemp + temp + hum + windspeed", data=data_train).fit()
print(model.params)
# Out:
# Intercept    1708.845113
# atemp       -3132.556967
# temp         8823.664422
# hum         -1134.940953
# windspeed   -3052.918412
# dtype: float64

# %% [markdown]
# statsmodels will give us a pretty comprehensive breakdown of our model. This gives us a lot of good info about the overall model and individual terms (coefficients).

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.748
# Model:                            OLS   Adj. R-squared:                  0.744
# Method:                 Least Squares   F-statistic:                     198.4
# Date:                Thu, 03 Mar 2022   Prob (F-statistic):           8.06e-79
# Time:                        02:25:56   Log-Likelihood:                -2190.2
# No. Observations:                 273   AIC:                             4390.
# Df Residuals:                     268   BIC:                             4408.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1708.8451    296.956      5.755      0.000    1124.182    2293.509
# atemp      -3132.5570   3164.040     -0.990      0.323   -9362.093    3096.979
# temp        8823.6644   2823.617      3.125      0.002    3264.372    1.44e+04
# hum        -1134.9410    302.778     -3.748      0.000   -1731.067    -538.815
# windspeed  -3052.9184    642.368     -4.753      0.000   -4317.647   -1788.190
# ==============================================================================
# Omnibus:                       15.311   Durbin-Watson:                   0.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.768
# Skew:                          -0.383   Prob(JB):                     1.14e-05
# Kurtosis:                       4.190   Cond. No.                         132.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Focussing on the coefficients first, we have the following:
# * coef: The estimate of the parameter
# * std err: The standard error, a measure of how much the coefficient changes by if we resample the data and recompute the regression
# * t: the tStat, $\frac{coeff}{std err}$, we want this to be a long way from 0, as it indicates that the term is less likely to be the result of noise
# * P: p-value for the null hypothesis that the coefficient is equal to 0. A low p-value means that you can reject the null hypothesis, i.e. that the term is significant.
# We also get some confidence intervals for the parameters.
#
# From this we see that the humidy and windspeed variables are more significant than our temperature variables. However, the scatter plots suggest that temperature is more important - both in terms of having a stronger visual trend and a higher correlation. We'll get back to why this is the case in a little bit.
#
# We also get some other "whole of model" details. These are:
# * No. observations: how many samples we have, in general, more is better (to a point, things get trickier when we can't fit the data in memory)
# * Df Residuals: This is one minus the number of parameters we are learning. If this is too small, we run a greater risk of overfitting
# * R-Squared: Proportion of observed variance explained by the model. A value of $1$ means the model explains everything, a value of $0$ means it explains nothing. Defined as follows:
#   * $R^2 = 1 - \frac{SSE}{SSY}$
#   * $SSE = \sum_{i=0}^{n} (y_i - \hat{y_i})^2$, SSE is the sum of the errors between the estimate and the actual value
#   * $SSY = \sum_{i=0}^{n} (y_i - \bar{y})^2$, SSY is sometimes also called SST (Total Sum of Squares), and is the sum of the differences from the mean
# * Adjusted R-Squared: Considers the model complexity (number of terms) alongside how much variance it explains. In short, really complex models (i.e. with lots of terms) are penalised.
# * F-statistic: Test statistic for the whole model. A p-value is also provided to indicate if the entire model is significant, much the same as we have for the individual components.
#
# We don't get an RMSE, but we can calculate that easily ourselves if we wish.

# %% [markdown]
# We can also use qqplots and histograms of residuals to see if our model is behaving.
#
# We expect our residuals to be normally distributed. On a qq-plot, that means they should form a straight line, for a histogram it means we should see a normal (bell) curve.

# %%
f = statsmodels.api.qqplot(model.resid)

# %%
fig = plt.figure(figsize=[8, 8])
ax = fig.add_subplot(1, 1, 1)
ax.hist(model.resid, 20);

# %% [markdown]
# We can see in both cases here our model is not perfect, but it's ok and appears to roughly follow a normal distribution.
#
# ### aTemp and Temp
#
# A little while back we mentioned the weird discrepancy in the p-values, where temp and atemp seemed less important, despite being more highly correlated with the model target than the other parameters.

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.748
# Model:                            OLS   Adj. R-squared:                  0.744
# Method:                 Least Squares   F-statistic:                     198.4
# Date:                Thu, 03 Mar 2022   Prob (F-statistic):           8.06e-79
# Time:                        02:25:57   Log-Likelihood:                -2190.2
# No. Observations:                 273   AIC:                             4390.
# Df Residuals:                     268   BIC:                             4408.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1708.8451    296.956      5.755      0.000    1124.182    2293.509
# atemp      -3132.5570   3164.040     -0.990      0.323   -9362.093    3096.979
# temp        8823.6644   2823.617      3.125      0.002    3264.372    1.44e+04
# hum        -1134.9410    302.778     -3.748      0.000   -1731.067    -538.815
# windspeed  -3052.9184    642.368     -4.753      0.000   -4317.647   -1788.190
# ==============================================================================
# Omnibus:                       15.311   Durbin-Watson:                   0.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.768
# Skew:                          -0.383   Prob(JB):                     1.14e-05
# Kurtosis:                       4.190   Cond. No.                         132.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# This is down to the these terms being co-linear. If we look at some scatter plots again:

# %%
fig = plt.figure(figsize=[24, 8])
ax = fig.add_subplot(1, 3, 1)
ax.scatter(data_train['atemp'], data_train['cnt'])
ax.set_xlabel('atemp')
ax.set_ylabel('cnt')
ax.set_title(str(data_train['atemp'].corr(data_train['cnt'])))
ax = fig.add_subplot(1, 3, 2)
ax.scatter(data_train['temp'], data_train['cnt'])
ax.set_xlabel('temp')
ax.set_ylabel('cnt')
ax.set_title(str(data_train['temp'].corr(data_train['cnt'])))
ax = fig.add_subplot(1, 3, 3)
ax.scatter(data_train['atemp'], data_train['temp'])
ax.set_xlabel('atemp')
ax.set_ylabel('temp')
ax.set_title(str(data_train['atemp'].corr(data_train['temp'])))
# Out:
# Text(0.5, 1.0, '0.9968816302544')

# %% [markdown]
# What we see is that the scatter plot between `temp` and `cnt` looks very much like that between `atemp` and `cnt`, and `atemp` and `temp` and very highly correlated. Essentially, both of these variables are modelling the same thing, and so when both are fed into our linear regression, one is redundant, and so both have a lower importance.
#
# Thinking about these variables, this makes sense. `aTemp` is the apparent temperature, and incorporates the actual air temp, the humidity and windspeed to give the temperature that it currently "feels like".

# %% [markdown]
# ## Improving the model
# Let's improve the model now. We'll drop the `atemp` variable, as we noted above that it's really a product of the other three variables. We'll also then print out the model summary, and have a look at our residuals.

# %%
model_2 = sm.ols(formula="cnt ~ temp + hum + windspeed", data=data_train).fit()
print(model_2.summary())
f = statsmodels.api.qqplot(model_2.resid)
fig = plt.figure(figsize=[8, 8])
ax = fig.add_subplot(1, 1, 1)
ax.hist(model_2.resid, 20)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.747
# Model:                            OLS   Adj. R-squared:                  0.744
# Method:                 Least Squares   F-statistic:                     264.2
# Date:                Thu, 03 Mar 2022   Prob (F-statistic):           7.43e-80
# Time:                        02:25:57   Log-Likelihood:                -2190.7
# No. Observations:                 273   AIC:                             4389.
# Df Residuals:                     269   BIC:                             4404.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1598.9598    275.424      5.805      0.000    1056.698    2141.222
# temp        6037.2059    227.171     26.576      0.000    5589.946    6484.466
# hum        -1144.5128    302.612     -3.782      0.000   -1740.303    -548.723
# windspeed  -2966.6479    636.407     -4.662      0.000   -4219.619   -1713.677
# ==============================================================================
# Omnibus:                       17.300   Durbin-Watson:                   0.962
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.957
# Skew:                          -0.441   Prob(JB):                     3.81e-06
# Kurtosis:                       4.191   Cond. No.                         19.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# (array([ 3.,  1.,  3.,  1.,  3.,  7.,  4., 16., 26., 30., 48., 39., 33.,
#         16., 19., 10.,  6.,  7.,  0.,  1.]),
#  array([-2548.08543462, -2313.98535126, -2079.88526791, -1845.78518455,
#         -1611.6851012 , -1377.58501784, -1143.48493448,  -909.38485113,
#          -675.28476777,  -441.18468442,  -207.08460106,    27.0154823 ,
#           261.11556565,   495.21564901,   729.31573236,   963.41581572,
#          1197.51589908,  1431.61598243,  1665.71606579,  1899.81614914,
#          2133.9162325 ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# The last thing we'll do is actually make some predictions with our model and plot them.

# %%
pred_train_orig = model.predict(data_train)
pred_test_orig = model.predict(data_test)
pred_train = model_2.predict(data_train)
pred_test = model_2.predict(data_test)
fig = plt.figure(figsize=[12, 8])
ax = fig.add_subplot(2, 1, 1)
ax.plot(pred_train_orig, label='Predicted (Model 1)')
ax.plot(pred_train, label='Predicted (Model 2)')
ax.plot(data_train['cnt'], label='Actual')
ax.set_title('Training Data')
ax.legend()
ax = fig.add_subplot(2, 1, 2)
ax.plot(pred_test_orig, label='Predicted (Model 1)')
ax.plot(pred_test, label='Predicted (Model 2)')
ax.plot(data_test['cnt'], label='Actual')
ax.set_title('Testing Data')
ax.legend()

# %% [markdown]
# We can see our model is not great, and tends to under estimate the actual usage. That said, the peaks and troughs present in the data are followed fairly well by the model.
#
# We also see that our two models are close to identical. This is not a shock, as the only variable we removed was essentially redundant. We can compute an error metric (such as root mean squared error) to further explore this:

# %%
import numpy
rmse_model1_train = numpy.sqrt(numpy.mean((pred_train_orig - data_train['cnt'])**2))
rmse_model1_test = numpy.sqrt(numpy.mean((pred_test_orig - data_test['cnt'])**2))
rmse_model2_train = numpy.sqrt(numpy.mean((pred_train - data_train['cnt'])**2))
rmse_model2_test = numpy.sqrt(numpy.mean((pred_test - data_test['cnt'])**2))

print('Model 1, Training Data RMSE: %f\nModel 1, Testing Data RMSE: %f\nModel 2, Training Data RMSE: %f\nModel 2, Testing Data RMSE: %f' % (rmse_model1_train, rmse_model1_test, rmse_model2_train, rmse_model2_test))
# Out:
# Model 1, Training Data RMSE: 737.888454
# Model 1, Testing Data RMSE: 1092.919429
# Model 2, Training Data RMSE: 739.236621
# Model 2, Testing Data RMSE: 1071.677030

# %% [markdown]
# We can see errors are pretty similar between the two models, model 1 is slightly better on the training and data, and slightly worse on the test data, but there's not much in it.
#
# In general, we may be concerned about the difference between train and test performance here. Often, having this gap between training and testing performance could indicate an element of overfitting, however we have a different situation going on here. We have data for a twelve month time period, and we've taken the last three months as our test set. Those three months have different weather conditions, and thus the reason for the loss of accuracy is more to do with the change in behaviour in the underlying system, and the fact that we may not have captured that properly in our model.

# %% [markdown]
# ## Randomly Split Data
#
# We can perform a random split on the data and re-train our model to see what happens. We get the following:

# %%
from sklearn.model_selection import train_test_split
data_train, data_test = train_test_split(data.loc[(data['yr'] == 0)], test_size=0.25, random_state=4)

model_3 = sm.ols(formula="cnt ~ temp + hum + windspeed", data=data_train).fit()
print(model_3.summary())
f = statsmodels.api.qqplot(model_3.resid)
fig = plt.figure(figsize=[8, 8])
ax = fig.add_subplot(1, 1, 1)
ax.hist(model_3.resid)

pred_train = model_3.predict(data_train)
pred_test = model_3.predict(data_test)
rmse_train = numpy.sqrt(numpy.mean((pred_train - data_train['cnt'])**2))
rmse_test = numpy.sqrt(numpy.mean((pred_test - data_test['cnt'])**2))

fig = plt.figure(figsize=[12, 8])
ax = fig.add_subplot(2, 1, 1)
ax.plot(numpy.arange(len(pred_train)), pred_train, label='Predicted (Model 3)')
ax.plot(numpy.arange(len(pred_train)), data_train['cnt'], label='Actual')
ax.set_title(rmse_train)
ax.legend()
ax = fig.add_subplot(2, 1, 2)
ax.plot(numpy.arange(len(pred_test)), pred_test, label='Predicted (Model 3)')
ax.plot(numpy.arange(len(pred_test)), data_test['cnt'], label='Actual')
ax.set_title(rmse_test)
ax.legend()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.661
# Model:                            OLS   Adj. R-squared:                  0.657
# Method:                 Least Squares   F-statistic:                     174.8
# Date:                Thu, 03 Mar 2022   Prob (F-statistic):           7.05e-63
# Time:                        02:25:58   Log-Likelihood:                -2217.6
# No. Observations:                 273   AIC:                             4443.
# Df Residuals:                     269   BIC:                             4458.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2596.2207    313.254      8.288      0.000    1979.480    3212.961
# temp        5650.7740    261.587     21.602      0.000    5135.756    6165.791
# hum        -1850.1187    353.531     -5.233      0.000   -2546.159   -1154.079
# windspeed  -3815.4536    658.426     -5.795      0.000   -5111.777   -2519.130
# ==============================================================================
# Omnibus:                        5.784   Durbin-Watson:                   2.039
# Prob(Omnibus):                  0.055   Jarque-Bera (JB):                5.804
# Skew:                          -0.357   Prob(JB):                       0.0549
# Kurtosis:                       2.973   Cond. No.                         18.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# The model is fairly similar to what we had before in terms of parameters and goodness of fit, but now we can see that the difference between the training set and testing set is smaller. By doing this, we now have the same data distribution in our train and test sets, so our model transfers between from one to the other as there is minimal disconnect there. This is something that we ideally always want - if the underlying structure or relationship in the data changes, then our model will likely suffer, so ensuring that our training set is properly representitive of what we are going to run it on is a really good idea (if it's possible and makes sense).
#
# Of course, when dealing with sequential data for a lot of reasons it makes sense to divide the data sequentially - i.e. do what we originally did and keep the first 9 months for the training and the rest for testing. I say this is better as it more accuratley simulates a real-world use case, i.e. we train the model on a bunch of historic data, and then test on new data as it's acquired.
#
# One thing to note now is our plots of predicted vs actual are now no longer sequential in time, so we can no longer see weekly patterns in the output for example.

# %% [markdown]
# ## Making things more complex
#
# Let's make the model more complex now, this will make it better (for a while), and ultimatley as we add too much complexity, make it worse.
#
# ### Categorical Variables
#
# We have a lot of other terms in our model that we can use, though most of the other terms we have are categorical variables (all the variables we've used so far are continuous). We incorporate categorical variables differently. We'll include two:
# * weekday, which is the day of the week
# * season, which is the season of the year
#
# Together, these will give our model more information about the day and time of year, and should help improve performance by allowing it to compensate for these factors.
#
# First up, we need to make sure that the data is registered as being categorical. This means that rather than our data in these columns being able to take on any value, they are restricted to a set of fixed categories.

# %%
data_train["weekday"] = data_train["weekday"].astype("category")
data_train["season"] = data_train["season"].astype("category")

data_test["weekday"] = data_test["weekday"].astype("category")
data_test["season"] = data_test["season"].astype("category")

# %% [markdown]
# At this point we can then fit our model as we normally would, and statsmodels will correctly treat these two new variables as categorical types.
#
# Note that depending on what package we're using for our regression, we may have to do this differently. Here, statsmodels is able to use the datatype information within the pandas table to work out how to handle each variable.

# %%
model_4 = sm.ols(formula="cnt ~ temp + hum + windspeed + weekday + season", data=data_train).fit()
print(model_4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.765
# Model:                            OLS   Adj. R-squared:                  0.754
# Method:                 Least Squares   F-statistic:                     70.47
# Date:                Thu, 03 Mar 2022   Prob (F-statistic):           1.73e-74
# Time:                        02:25:59   Log-Likelihood:                -2167.6
# No. Observations:                 273   AIC:                             4361.
# Df Residuals:                     260   BIC:                             4408.
# Df Model:                          12
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     2605.2645    286.406      9.096      0.000    2041.293    3169.236
# weekday[T.1]   -10.8566    154.213     -0.070      0.944    -314.521     292.808
# weekday[T.2]    19.0968    153.363      0.125      0.901    -282.895     321.088
# weekday[T.3]  -151.7631    154.900     -0.980      0.328    -456.781     153.255
# weekday[T.4]    16.9222    161.837      0.105      0.917    -301.755     335.600
# weekday[T.5]   -76.3188    156.169     -0.489      0.625    -383.836     231.199
# weekday[T.6]    10.4332    154.598      0.067      0.946    -293.991     314.858
# season[T.2]   1068.4496    170.264      6.275      0.000     733.178    1403.721
# season[T.3]    765.4665    217.673      3.517      0.001     336.839    1194.093
# season[T.4]   1384.5180    145.612      9.508      0.000    1097.789    1671.247
# temp          4767.0557    409.789     11.633      0.000    3960.128    5573.984
# hum          -2523.4368    313.516     -8.049      0.000   -3140.790   -1906.084
# windspeed    -3422.4327    576.387     -5.938      0.000   -4557.413   -2287.452
# ==============================================================================
# Omnibus:                       29.516   Durbin-Watson:                   1.972
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.658
# Skew:                          -0.791   Prob(JB):                     1.10e-08
# Kurtosis:                       3.850   Cond. No.                         20.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# What that means is we get the above. We've added two variables, but got 9 new terms. The two variables we added have:
# * 7 categories for week day
# * 4 categories for season
#
# We can look at these as not being 2 variables, but rather as being a set of 7 and a set of 4 mutally exclusive variables, which can either be true or false. Given that each of these can either be true or false, there is no "slope", just a constant. In effect, what happens is that each category adds a new intercept value that will be included when the appropriate category is set to true. The first category of each is incoroprated into the main intercept, hence we get (number of categories - 1) new terms.
#
# Considering p-values for the terms, we consider these as a set, and if one value of the category is significant, we keep them all. In our case, we can see that weekday is not significant (all p values are well over 0.05), while for season all terms are significant.

# %% [markdown]
# We'll remove week day from the data, and re-train our model.

# %%
model_5 = sm.ols(formula="cnt ~ temp + hum + windspeed + season", data=data_train).fit()
print(model_5.summary())

f = statsmodels.api.qqplot(model_5.resid)
fig = plt.figure(figsize=[8, 8])
ax = fig.add_subplot(1, 1, 1)
ax.hist(model_5.resid)

pred_train = model_5.predict(data_train)
pred_test = model_5.predict(data_test)
rmse_train = numpy.sqrt(numpy.mean((pred_train - data_train['cnt'])**2))
rmse_test = numpy.sqrt(numpy.mean((pred_test - data_test['cnt'])**2))

fig = plt.figure(figsize=[12, 8])
ax = fig.add_subplot(2, 1, 1)
ax.plot(numpy.arange(len(pred_train)), pred_train, label='Predicted (Model 5)')
ax.plot(numpy.arange(len(pred_train)), data_train['cnt'], label='Actual')
ax.set_title(rmse_train)
ax.legend()
ax = fig.add_subplot(2, 1, 2)
ax.plot(numpy.arange(len(pred_test)), pred_test, label='Predicted (Model 5)')
ax.plot(numpy.arange(len(pred_test)), data_test['cnt'], label='Actual')
ax.set_title(rmse_test)
ax.legend()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.763
# Model:                            OLS   Adj. R-squared:                  0.758
# Method:                 Least Squares   F-statistic:                     142.8
# Date:                Thu, 03 Mar 2022   Prob (F-statistic):           3.51e-80
# Time:                        02:25:59   Log-Likelihood:                -2168.7
# No. Observations:                 273   AIC:                             4351.
# Df Residuals:                     266   BIC:                             4377.
# Df Model:                           6
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    2608.7335    270.398      9.648      0.000    2076.341    3141.126
# season[T.2]  1074.1630    168.775      6.364      0.000     741.858    1406.467
# season[T.3]   779.1809    215.114      3.622      0.000     355.639    1202.723
# season[T.4]  1383.6264    144.230      9.593      0.000    1099.649    1667.604
# temp         4744.1777    405.592     11.697      0.000    3945.598    5542.757
# hum         -2560.7859    304.762     -8.403      0.000   -3160.838   -1960.734
# windspeed   -3425.7474    564.999     -6.063      0.000   -4538.187   -2313.308
# ==============================================================================
# Omnibus:                       29.312   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.283
# Skew:                          -0.789   Prob(JB):                     1.32e-08
# Kurtosis:                       3.837   Cond. No.                         19.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# We can see now that our model is much more accurate with that categorical term incorporated.

# %% [markdown]
# ### Higher Order Terms and Overfitting
#
# In general, as we add more and more terms, performance will improve. Terms do not have to be totally separate things either. We can create new terms (or features) by combining existing terms. In this case, we'll add interaction terms that capture the product of each term with each other term.

# %%
model_6 = sm.ols(formula="cnt ~ temp * hum * windspeed * season", data=data_train).fit()
print(model_6.summary())

f = statsmodels.api.qqplot(model_6.resid)
fig = plt.figure(figsize=[8, 8])
ax = fig.add_subplot(1, 1, 1)
ax.hist(model_5.resid)

pred_train = model_6.predict(data_train)
pred_test = model_6.predict(data_test)
rmse_train = numpy.sqrt(numpy.mean((pred_train - data_train['cnt'])**2))
rmse_test = numpy.sqrt(numpy.mean((pred_test - data_test['cnt'])**2))

fig = plt.figure(figsize=[12, 8])
ax = fig.add_subplot(2, 1, 1)
ax.plot(numpy.arange(len(pred_train)), pred_train, label='Predicted (Model 6)')
ax.plot(numpy.arange(len(pred_train)), data_train['cnt'], label='Actual')
ax.set_title(rmse_train)
ax.legend()
ax = fig.add_subplot(2, 1, 2)
ax.plot(numpy.arange(len(pred_test)), pred_test, label='Predicted (Model 6)')
ax.plot(numpy.arange(len(pred_test)), data_test['cnt'], label='Actual')
ax.set_title(rmse_test)
ax.legend()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.852
# Method:                 Least Squares   F-statistic:                     51.38
# Date:                Thu, 03 Mar 2022   Prob (F-statistic):           9.17e-89
# Time:                        02:26:00   Log-Likelihood:                -2088.2
# No. Observations:                 273   AIC:                             4240.
# Df Residuals:                     241   BIC:                             4356.
# Df Model:                          31
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                       1082.7709   2333.167      0.464      0.643   -3513.233    5678.775
# season[T.2]                    -6898.7842   6204.464     -1.112      0.267   -1.91e+04    5323.117
# season[T.3]                     5.154e+04   1.26e+04      4.099      0.000    2.68e+04    7.63e+04
# season[T.4]                    -5938.2978   4172.649     -1.423      0.156   -1.42e+04    2281.221
# temp                            1.016e+04   8239.096      1.233      0.219   -6069.961    2.64e+04
# temp:season[T.2]                7028.9718   1.36e+04      0.516      0.606   -1.98e+04    3.38e+04
# temp:season[T.3]               -7.963e+04   1.97e+04     -4.052      0.000   -1.18e+05   -4.09e+04
# temp:season[T.4]                1.616e+04   1.13e+04      1.428      0.154   -6127.541    3.85e+04
# hum                             -970.0640   4090.111     -0.237      0.813   -9026.995    7086.867
# hum:season[T.2]                 1.775e+04   9484.886      1.872      0.062    -932.571    3.64e+04
# hum:season[T.3]                -6.509e+04   1.66e+04     -3.915      0.000   -9.78e+04   -3.23e+04
# hum:season[T.4]                 1.061e+04   6546.346      1.620      0.106   -2287.295    2.35e+04
# temp:hum                       -7328.2862   1.48e+04     -0.496      0.620   -3.64e+04    2.18e+04
# temp:hum:season[T.2]           -2.065e+04    2.2e+04     -0.938      0.349    -6.4e+04    2.27e+04
# temp:hum:season[T.3]            1.049e+05    2.8e+04      3.746      0.000    4.97e+04     1.6e+05
# temp:hum:season[T.4]           -2.115e+04   1.84e+04     -1.152      0.250   -5.73e+04     1.5e+04
# windspeed                        422.6659      1e+04      0.042      0.966   -1.93e+04    2.01e+04
# windspeed:season[T.2]           3.388e+04    2.7e+04      1.256      0.210   -1.92e+04     8.7e+04
# windspeed:season[T.3]          -1.539e+05   7.22e+04     -2.132      0.034   -2.96e+05   -1.17e+04
# windspeed:season[T.4]           2.111e+04   2.18e+04      0.966      0.335   -2.19e+04    6.42e+04
# temp:windspeed                 -1.734e+04   2.96e+04     -0.585      0.559   -7.57e+04     4.1e+04
# temp:windspeed:season[T.2]     -3.287e+04    5.5e+04     -0.598      0.551   -1.41e+05    7.55e+04
# temp:windspeed:season[T.3]        2.6e+05   1.07e+05      2.433      0.016    4.95e+04    4.71e+05
# temp:windspeed:season[T.4]     -2.516e+04   5.28e+04     -0.476      0.634   -1.29e+05    7.89e+04
# hum:windspeed                  -2312.5298   1.86e+04     -0.124      0.901   -3.89e+04    3.43e+04
# hum:windspeed:season[T.2]      -8.497e+04   4.17e+04     -2.038      0.043   -1.67e+05   -2835.040
# hum:windspeed:season[T.3]         2.1e+05   9.17e+04      2.291      0.023    2.94e+04    3.91e+05
# hum:windspeed:season[T.4]      -3.653e+04    3.6e+04     -1.015      0.311   -1.07e+05    3.44e+04
# temp:hum:windspeed              2.391e+04   5.85e+04      0.409      0.683   -9.13e+04    1.39e+05
# temp:hum:windspeed:season[T.2]  1.088e+05   9.12e+04      1.192      0.234   -7.09e+04    2.88e+05
# temp:hum:windspeed:season[T.3] -3.664e+05   1.44e+05     -2.549      0.011   -6.49e+05   -8.33e+04
# temp:hum:windspeed:season[T.4]  3.735e+04    8.9e+04      0.420      0.675   -1.38e+05    2.13e+05
# ==============================================================================
# Omnibus:                       25.517   Durbin-Watson:                   1.937
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.248
# Skew:                          -0.484   Prob(JB):                     4.51e-12
# Kurtosis:                       4.912   Cond. No.                     1.02e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.02e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# We can see this gives us a much bigger model, but it's much more accurate too.
#
# Of course we can go too far with this, and start to add in quatratic terms as well.

# %%
model_6 = sm.ols(formula="cnt ~ temp * hum * windspeed * season * numpy.power(temp, 2) * numpy.power(hum, 2) * numpy.power(windspeed, 2)", data=data_train).fit()
print(model_6.summary())

f = statsmodels.api.qqplot(model_6.resid)
fig = plt.figure(figsize=[8, 8])
ax = fig.add_subplot(1, 1, 1)
ax.hist(model_5.resid)

pred_train = model_6.predict(data_train)
pred_test = model_6.predict(data_test)
rmse_train = numpy.sqrt(numpy.mean((pred_train - data_train['cnt'])**2))
rmse_test = numpy.sqrt(numpy.mean((pred_test - data_test['cnt'])**2))

fig = plt.figure(figsize=[12, 8])
ax = fig.add_subplot(2, 1, 1)
ax.plot(numpy.arange(len(pred_train)), pred_train, label='Predicted (Model 6)')
ax.plot(numpy.arange(len(pred_train)), data_train['cnt'], label='Actual')
ax.set_title(rmse_train)
ax.legend()
ax = fig.add_subplot(2, 1, 2)
ax.plot(numpy.arange(len(pred_test)), pred_test, label='Predicted (Model 6)')
ax.plot(numpy.arange(len(pred_test)), data_test['cnt'], label='Actual')
ax.set_title(rmse_test)
ax.legend()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     19.57
# Date:                Thu, 03 Mar 2022   Prob (F-statistic):           2.88e-10
# Time:                        02:26:01   Log-Likelihood:                -1612.9
# No. Observations:                 273   AIC:                             3732.
# Df Residuals:                      20   BIC:                             4645.
# Df Model:                         252
# Covariance Type:            nonrobust
# =====================================================================================================================================================================
#                                                                                                         coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                         -1.984e+08   6.53e+08     -0.304      0.764   -1.56e+09    1.16e+09
# season[T.2]                                                                                       -7.127e+09   6.12e+09     -1.164      0.258   -1.99e+10    5.64e+09
# season[T.3]                                                                                       -6.005e+09   1.46e+10     -0.412      0.685   -3.64e+10    2.44e+10
# season[T.4]                                                                                        1.014e+09   7.35e+08      1.380      0.183   -5.19e+08    2.55e+09
# temp                                                                                                1.57e+09   4.44e+09      0.353      0.728    -7.7e+09    1.08e+10
# temp:season[T.2]                                                                                    3.67e+10   3.01e+10      1.218      0.237   -2.61e+10    9.95e+10
# temp:season[T.3]                                                                                   2.548e+10   6.25e+10      0.408      0.688   -1.05e+11    1.56e+11
# temp:season[T.4]                                                                                  -8.317e+09   5.08e+09     -1.636      0.117   -1.89e+10    2.29e+09
# hum                                                                                                1.533e+09   4.67e+09      0.328      0.746   -8.21e+09    1.13e+10
# hum:season[T.2]                                                                                    2.859e+10   2.48e+10      1.154      0.262   -2.31e+10    8.03e+10
# hum:season[T.3]                                                                                    2.137e+10   6.75e+10      0.317      0.755   -1.19e+11    1.62e+11
# hum:season[T.4]                                                                                   -5.226e+09   4.88e+09     -1.070      0.297   -1.54e+10    4.96e+09
# temp:hum                                                                                          -1.437e+10    3.9e+10     -0.368      0.717   -9.58e+10     6.7e+10
# temp:hum:season[T.2]                                                                              -1.436e+11   1.23e+11     -1.163      0.258   -4.01e+11    1.14e+11
# temp:hum:season[T.3]                                                                               -8.58e+10   2.79e+11     -0.307      0.762   -6.68e+11    4.97e+11
# temp:hum:season[T.4]                                                                               4.437e+10   4.02e+10      1.104      0.283   -3.94e+10    1.28e+11
# windspeed                                                                                           3.16e+09   9.85e+09      0.321      0.752   -1.74e+10    2.37e+10
# windspeed:season[T.2]                                                                              9.889e+10    7.8e+10      1.267      0.220   -6.39e+10    2.62e+11
# windspeed:season[T.3]                                                                               1.31e+11   2.71e+11      0.483      0.634   -4.34e+11    6.96e+11
# windspeed:season[T.4]                                                                              -1.91e+10    1.2e+10     -1.589      0.128   -4.42e+10    5.98e+09
# temp:windspeed                                                                                    -2.589e+10   6.93e+10     -0.374      0.713    -1.7e+11    1.19e+11
# temp:windspeed:season[T.2]                                                                        -5.118e+11   3.86e+11     -1.328      0.199   -1.32e+12    2.92e+11
# temp:windspeed:season[T.3]                                                                        -5.568e+11   1.16e+12     -0.482      0.635   -2.97e+12    1.86e+12
# temp:windspeed:season[T.4]                                                                         1.511e+11   8.44e+10      1.791      0.088   -2.49e+10    3.27e+11
# hum:windspeed                                                                                     -2.333e+10   6.76e+10     -0.345      0.733   -1.64e+11    1.18e+11
# hum:windspeed:season[T.2]                                                                         -3.958e+11   3.11e+11     -1.272      0.218   -1.05e+12    2.54e+11
# hum:windspeed:season[T.3]                                                                         -4.933e+11   1.25e+12     -0.393      0.698   -3.11e+12    2.12e+12
# hum:windspeed:season[T.4]                                                                          9.872e+10   7.44e+10      1.326      0.200   -5.65e+10    2.54e+11
# temp:hum:windspeed                                                                                 2.224e+11    5.7e+11      0.390      0.700   -9.66e+11    1.41e+12
# temp:hum:windspeed:season[T.2]                                                                     1.994e+12   1.57e+12      1.273      0.218   -1.27e+12    5.26e+12
# temp:hum:windspeed:season[T.3]                                                                     2.027e+12   5.22e+12      0.388      0.702   -8.87e+12    1.29e+13
# temp:hum:windspeed:season[T.4]                                                                    -8.018e+11   6.05e+11     -1.325      0.200   -2.06e+12     4.6e+11
# numpy.power(temp, 2)                                                                              -3.298e+09   7.59e+09     -0.434      0.669   -1.91e+10    1.25e+10
# season[T.2]:numpy.power(temp, 2)                                                                  -6.397e+10   4.81e+10     -1.329      0.199   -1.64e+11    3.64e+10
# season[T.3]:numpy.power(temp, 2)                                                                  -3.617e+10   9.57e+10     -0.378      0.709   -2.36e+11    1.63e+11
# season[T.4]:numpy.power(temp, 2)                                                                   2.085e+10   9.67e+09      2.155      0.043    6.71e+08     4.1e+10
# temp:numpy.power(temp, 2)                                                                          3.185e+09   1.69e+10      0.188      0.853   -3.22e+10    3.85e+10
# temp:season[T.2]:numpy.power(temp, 2)                                                              3.658e+10   2.97e+10      1.230      0.233   -2.54e+10    9.86e+10
# temp:season[T.3]:numpy.power(temp, 2)                                                              1.607e+10    6.1e+10      0.263      0.795   -1.11e+11    1.43e+11
# temp:season[T.4]:numpy.power(temp, 2)                                                             -1.759e+10   1.76e+10     -0.997      0.331   -5.44e+10    1.92e+10
# hum:numpy.power(temp, 2)                                                                           4.158e+10   8.74e+10      0.476      0.639   -1.41e+11    2.24e+11
# hum:season[T.2]:numpy.power(temp, 2)                                                               2.373e+11   2.02e+11      1.177      0.253   -1.83e+11    6.58e+11
# hum:season[T.3]:numpy.power(temp, 2)                                                               1.052e+11   3.92e+11      0.268      0.791   -7.13e+11    9.23e+11
# hum:season[T.4]:numpy.power(temp, 2)                                                              -1.187e+11      9e+10     -1.319      0.202   -3.06e+11     6.9e+10
# temp:hum:numpy.power(temp, 2)                                                                      -4.68e+10   6.64e+10     -0.705      0.489   -1.85e+11    9.17e+10
# temp:hum:season[T.2]:numpy.power(temp, 2)                                                         -1.191e+11   1.11e+11     -1.075      0.295    -3.5e+11    1.12e+11
# temp:hum:season[T.3]:numpy.power(temp, 2)                                                         -2.518e+10   2.18e+11     -0.115      0.909   -4.81e+11     4.3e+11
# temp:hum:season[T.4]:numpy.power(temp, 2)                                                          1.096e+11   6.83e+10      1.603      0.125    -3.3e+10    2.52e+11
# windspeed:numpy.power(temp, 2)                                                                     5.111e+10   8.74e+10      0.585      0.565   -1.31e+11    2.33e+11
# windspeed:season[T.2]:numpy.power(temp, 2)                                                         9.003e+11    6.1e+11      1.475      0.156   -3.73e+11    2.17e+12
# windspeed:season[T.3]:numpy.power(temp, 2)                                                         7.952e+11   1.72e+12      0.462      0.649   -2.79e+12    4.39e+12
# windspeed:season[T.4]:numpy.power(temp, 2)                                                        -3.666e+11   1.43e+11     -2.570      0.018   -6.64e+11    -6.9e+10
# temp:windspeed:numpy.power(temp, 2)                                                               -3.037e+10    1.7e+11     -0.178      0.860   -3.86e+11    3.25e+11
# temp:windspeed:season[T.2]:numpy.power(temp, 2)                                                   -5.349e+11   3.52e+11     -1.519      0.144   -1.27e+12       2e+11
# temp:windspeed:season[T.3]:numpy.power(temp, 2)                                                   -3.806e+11   1.01e+12     -0.377      0.710   -2.48e+12    1.72e+12
# temp:windspeed:season[T.4]:numpy.power(temp, 2)                                                    2.846e+11   1.92e+11      1.481      0.154   -1.16e+11    6.85e+11
# hum:windspeed:numpy.power(temp, 2)                                                                -6.223e+11   1.23e+12     -0.505      0.619   -3.19e+12    1.95e+12
# hum:windspeed:season[T.2]:numpy.power(temp, 2)                                                     -3.32e+12   2.57e+12     -1.294      0.210   -8.67e+12    2.03e+12
# hum:windspeed:season[T.3]:numpy.power(temp, 2)                                                    -2.653e+12   7.28e+12     -0.365      0.719   -1.78e+13    1.25e+13
# hum:windspeed:season[T.4]:numpy.power(temp, 2)                                                     2.059e+12   1.31e+12      1.572      0.132   -6.73e+11    4.79e+12
# temp:hum:windspeed:numpy.power(temp, 2)                                                            6.165e+11   6.39e+11      0.965      0.346   -7.16e+11    1.95e+12
# temp:hum:windspeed:season[T.2]:numpy.power(temp, 2)                                                 1.74e+12   1.25e+12      1.388      0.180   -8.74e+11    4.36e+12
# temp:hum:windspeed:season[T.3]:numpy.power(temp, 2)                                                  9.8e+11   3.75e+12      0.261      0.797   -6.85e+12    8.81e+12
# temp:hum:windspeed:season[T.4]:numpy.power(temp, 2)                                               -1.761e+12   7.17e+11     -2.456      0.023   -3.26e+12   -2.65e+11
# numpy.power(hum, 2)                                                                               -3.568e+09   1.01e+10     -0.353      0.727   -2.46e+10    1.75e+10
# season[T.2]:numpy.power(hum, 2)                                                                    -3.76e+10   3.34e+10     -1.125      0.274   -1.07e+11    3.21e+10
# season[T.3]:numpy.power(hum, 2)                                                                   -2.311e+10   1.03e+11     -0.225      0.824   -2.37e+11    1.91e+11
# season[T.4]:numpy.power(hum, 2)                                                                    9.184e+09   1.03e+10      0.892      0.383   -1.23e+10    3.07e+10
# temp:numpy.power(hum, 2)                                                                           3.649e+10   9.38e+10      0.389      0.701   -1.59e+11    2.32e+11
# temp:season[T.2]:numpy.power(hum, 2)                                                               1.803e+11   1.77e+11      1.020      0.320   -1.89e+11    5.49e+11
# temp:season[T.3]:numpy.power(hum, 2)                                                               8.057e+10   4.07e+11      0.198      0.845   -7.68e+11    9.29e+11
# temp:season[T.4]:numpy.power(hum, 2)                                                              -8.122e+10   9.45e+10     -0.860      0.400   -2.78e+11    1.16e+11
# hum:numpy.power(hum, 2)                                                                            2.566e+09   6.76e+09      0.380      0.708   -1.15e+10    1.67e+10
# hum:season[T.2]:numpy.power(hum, 2)                                                                1.615e+10   1.52e+10      1.061      0.301   -1.56e+10    4.79e+10
# hum:season[T.3]:numpy.power(hum, 2)                                                                7.261e+09   5.15e+10      0.141      0.889      -1e+11    1.15e+11
# hum:season[T.4]:numpy.power(hum, 2)                                                               -5.437e+09   6.82e+09     -0.797      0.435   -1.97e+10    8.79e+09
# temp:hum:numpy.power(hum, 2)                                                                      -2.765e+10   6.68e+10     -0.414      0.683   -1.67e+11    1.12e+11
# temp:hum:season[T.2]:numpy.power(hum, 2)                                                          -7.146e+10   9.14e+10     -0.782      0.443   -2.62e+11    1.19e+11
# temp:hum:season[T.3]:numpy.power(hum, 2)                                                          -1.562e+10   1.94e+11     -0.081      0.937    -4.2e+11    3.88e+11
# temp:hum:season[T.4]:numpy.power(hum, 2)                                                           5.005e+10   6.69e+10      0.748      0.463   -8.95e+10     1.9e+11
# windspeed:numpy.power(hum, 2)                                                                       5.28e+10   1.42e+11      0.373      0.713   -2.42e+11    3.48e+11
# windspeed:season[T.2]:numpy.power(hum, 2)                                                          5.194e+11   4.15e+11      1.251      0.225   -3.46e+11    1.39e+12
# windspeed:season[T.3]:numpy.power(hum, 2)                                                          5.863e+11   1.91e+12      0.306      0.762    -3.4e+12    4.58e+12
# windspeed:season[T.4]:numpy.power(hum, 2)                                                         -1.722e+11   1.49e+11     -1.153      0.263   -4.84e+11    1.39e+11
# temp:windspeed:numpy.power(hum, 2)                                                                 -5.47e+11   1.31e+12     -0.416      0.682   -3.29e+12     2.2e+12
# temp:windspeed:season[T.2]:numpy.power(hum, 2)                                                    -2.493e+12   2.25e+12     -1.108      0.281   -7.19e+12     2.2e+12
# temp:windspeed:season[T.3]:numpy.power(hum, 2)                                                     -2.24e+12   7.73e+12     -0.290      0.775   -1.84e+13    1.39e+13
# temp:windspeed:season[T.4]:numpy.power(hum, 2)                                                     1.445e+12   1.35e+12      1.074      0.296   -1.36e+12    4.25e+12
# hum:windspeed:numpy.power(hum, 2)                                                                 -3.724e+10   9.22e+10     -0.404      0.691    -2.3e+11    1.55e+11
# hum:windspeed:season[T.2]:numpy.power(hum, 2)                                                     -2.228e+11   1.88e+11     -1.183      0.251   -6.16e+11     1.7e+11
# hum:windspeed:season[T.3]:numpy.power(hum, 2)                                                     -2.189e+11   9.61e+11     -0.228      0.822   -2.22e+12    1.78e+12
# hum:windspeed:season[T.4]:numpy.power(hum, 2)                                                      1.005e+11   9.54e+10      1.053      0.305   -9.85e+10       3e+11
# temp:hum:windspeed:numpy.power(hum, 2)                                                             4.062e+11   9.08e+11      0.447      0.659   -1.49e+12     2.3e+12
# temp:hum:windspeed:season[T.2]:numpy.power(hum, 2)                                                 9.838e+11   1.17e+12      0.838      0.412   -1.46e+12    3.43e+12
# temp:hum:windspeed:season[T.3]:numpy.power(hum, 2)                                                 7.127e+11   3.75e+12      0.190      0.851   -7.11e+12    8.54e+12
# temp:hum:windspeed:season[T.4]:numpy.power(hum, 2)                                                -8.728e+11   9.18e+11     -0.951      0.353   -2.79e+12    1.04e+12
# numpy.power(temp, 2):numpy.power(hum, 2)                                                          -1.193e+11   2.58e+11     -0.463      0.648   -6.57e+11    4.18e+11
# season[T.2]:numpy.power(temp, 2):numpy.power(hum, 2)                                              -2.658e+11   3.41e+11     -0.779      0.445   -9.77e+11    4.46e+11
# season[T.3]:numpy.power(temp, 2):numpy.power(hum, 2)                                              -5.297e+10   5.06e+11     -0.105      0.918   -1.11e+12       1e+12
# season[T.4]:numpy.power(temp, 2):numpy.power(hum, 2)                                               2.328e+11   2.58e+11      0.901      0.378   -3.06e+11    7.71e+11
# temp:numpy.power(temp, 2):numpy.power(hum, 2)                                                      1.423e+11   2.24e+11      0.635      0.533   -3.25e+11     6.1e+11
# temp:season[T.2]:numpy.power(temp, 2):numpy.power(hum, 2)                                          8.842e+10   2.45e+11      0.361      0.722   -4.23e+11    5.99e+11
# temp:season[T.3]:numpy.power(temp, 2):numpy.power(hum, 2)                                         -5.728e+10   2.35e+11     -0.244      0.810   -5.47e+11    4.32e+11
# temp:season[T.4]:numpy.power(temp, 2):numpy.power(hum, 2)                                         -2.338e+11   2.24e+11     -1.043      0.309   -7.01e+11    2.34e+11
# hum:numpy.power(temp, 2):numpy.power(hum, 2)                                                       9.654e+10   2.03e+11      0.475      0.640   -3.28e+11    5.21e+11
# hum:season[T.2]:numpy.power(temp, 2):numpy.power(hum, 2)                                           8.084e+10   2.21e+11      0.365      0.719   -3.81e+11    5.43e+11
# hum:season[T.3]:numpy.power(temp, 2):numpy.power(hum, 2)                                          -3.246e+10   2.07e+11     -0.157      0.877   -4.65e+11       4e+11
# hum:season[T.4]:numpy.power(temp, 2):numpy.power(hum, 2)                                          -1.525e+11   2.03e+11     -0.751      0.462   -5.76e+11    2.71e+11
# temp:hum:numpy.power(temp, 2):numpy.power(hum, 2)                                                 -1.192e+11   2.02e+11     -0.591      0.561    -5.4e+11    3.02e+11
# temp:hum:season[T.2]:numpy.power(temp, 2):numpy.power(hum, 2)                                      1.205e+10   2.04e+11      0.059      0.953   -4.13e+11    4.38e+11
# temp:hum:season[T.3]:numpy.power(temp, 2):numpy.power(hum, 2)                                       8.73e+10   1.09e+11      0.802      0.432    -1.4e+11    3.14e+11
# temp:hum:season[T.4]:numpy.power(temp, 2):numpy.power(hum, 2)                                      1.639e+11   2.01e+11      0.814      0.425   -2.56e+11    5.84e+11
# windspeed:numpy.power(temp, 2):numpy.power(hum, 2)                                                 1.757e+12   3.52e+12      0.499      0.624   -5.59e+12    9.11e+12
# windspeed:season[T.2]:numpy.power(temp, 2):numpy.power(hum, 2)                                     3.684e+12   4.43e+12      0.832      0.415   -5.55e+12    1.29e+13
# windspeed:season[T.3]:numpy.power(temp, 2):numpy.power(hum, 2)                                     2.314e+12   9.85e+12      0.235      0.817   -1.82e+13    2.29e+13
# windspeed:season[T.4]:numpy.power(temp, 2):numpy.power(hum, 2)                                    -3.948e+12   3.56e+12     -1.107      0.281   -1.14e+13    3.49e+12
# temp:windspeed:numpy.power(temp, 2):numpy.power(hum, 2)                                           -1.977e+12   2.82e+12     -0.701      0.491   -7.86e+12     3.9e+12
# temp:windspeed:season[T.2]:numpy.power(temp, 2):numpy.power(hum, 2)                               -1.299e+12   3.04e+12     -0.428      0.673   -7.63e+12    5.04e+12
# temp:windspeed:season[T.3]:numpy.power(temp, 2):numpy.power(hum, 2)                               -1.444e+10   4.13e+12     -0.003      0.997   -8.63e+12     8.6e+12
# temp:windspeed:season[T.4]:numpy.power(temp, 2):numpy.power(hum, 2)                                3.701e+12   2.84e+12      1.305      0.207   -2.21e+12    9.62e+12
# hum:windspeed:numpy.power(temp, 2):numpy.power(hum, 2)                                            -1.406e+12   2.71e+12     -0.520      0.609   -7.05e+12    4.24e+12
# hum:windspeed:season[T.2]:numpy.power(temp, 2):numpy.power(hum, 2)                                  -1.1e+12   2.89e+12     -0.381      0.707   -7.13e+12    4.93e+12
# hum:windspeed:season[T.3]:numpy.power(temp, 2):numpy.power(hum, 2)                                -2.342e+11   4.28e+12     -0.055      0.957   -9.16e+12    8.69e+12
# hum:windspeed:season[T.4]:numpy.power(temp, 2):numpy.power(hum, 2)                                 2.526e+12   2.71e+12      0.932      0.363   -3.13e+12    8.18e+12
# temp:hum:windspeed:numpy.power(temp, 2):numpy.power(hum, 2)                                        1.684e+12   2.57e+12      0.654      0.521   -3.69e+12    7.05e+12
# temp:hum:windspeed:season[T.2]:numpy.power(temp, 2):numpy.power(hum, 2)                           -1.618e+11   2.59e+12     -0.062      0.951   -5.56e+12    5.24e+12
# temp:hum:windspeed:season[T.3]:numpy.power(temp, 2):numpy.power(hum, 2)                           -8.769e+11   1.44e+12     -0.611      0.548   -3.87e+12    2.12e+12
# temp:hum:windspeed:season[T.4]:numpy.power(temp, 2):numpy.power(hum, 2)                           -2.553e+12   2.57e+12     -0.993      0.332   -7.92e+12    2.81e+12
# numpy.power(windspeed, 2)                                                                         -1.698e+10   5.37e+10     -0.316      0.755   -1.29e+11    9.51e+10
# season[T.2]:numpy.power(windspeed, 2)                                                             -4.567e+11   3.33e+11     -1.373      0.185   -1.15e+12    2.37e+11
# season[T.3]:numpy.power(windspeed, 2)                                                             -9.403e+11   1.64e+12     -0.573      0.573   -4.37e+12    2.48e+12
# season[T.4]:numpy.power(windspeed, 2)                                                              1.214e+11   6.95e+10      1.746      0.096   -2.37e+10    2.66e+11
# temp:numpy.power(windspeed, 2)                                                                      1.51e+11   4.18e+11      0.361      0.722   -7.21e+11    1.02e+12
# temp:season[T.2]:numpy.power(windspeed, 2)                                                          2.36e+12   1.66e+12      1.420      0.171   -1.11e+12    5.83e+12
# temp:season[T.3]:numpy.power(windspeed, 2)                                                         3.991e+12   6.96e+12      0.573      0.573   -1.05e+13    1.85e+13
# temp:season[T.4]:numpy.power(windspeed, 2)                                                        -9.338e+11   5.13e+11     -1.821      0.084      -2e+12    1.36e+11
# hum:numpy.power(windspeed, 2)                                                                      1.186e+11   3.48e+11      0.341      0.737   -6.07e+11    8.44e+11
# hum:season[T.2]:numpy.power(windspeed, 2)                                                          1.827e+12   1.31e+12      1.390      0.180   -9.14e+11    4.57e+12
# hum:season[T.3]:numpy.power(windspeed, 2)                                                          3.701e+12   7.59e+12      0.487      0.631   -1.21e+13    1.95e+13
# hum:season[T.4]:numpy.power(windspeed, 2)                                                         -6.302e+11   4.07e+11     -1.548      0.137   -1.48e+12    2.19e+11
# temp:hum:numpy.power(windspeed, 2)                                                                 -1.18e+12   3.06e+12     -0.385      0.704   -7.57e+12    5.21e+12
# temp:hum:season[T.2]:numpy.power(windspeed, 2)                                                    -9.173e+12    6.8e+12     -1.349      0.192   -2.34e+13    5.01e+12
# temp:hum:season[T.3]:numpy.power(windspeed, 2)                                                    -1.537e+13   3.16e+13     -0.486      0.632   -8.13e+13    5.06e+13
# temp:hum:season[T.4]:numpy.power(windspeed, 2)                                                     4.937e+12   3.35e+12      1.475      0.156   -2.04e+12    1.19e+13
# windspeed:numpy.power(windspeed, 2)                                                                3.147e+10   1.02e+11      0.310      0.760    -1.8e+11    2.43e+11
# windspeed:season[T.2]:numpy.power(windspeed, 2)                                                    7.007e+11   4.76e+11      1.473      0.156   -2.92e+11    1.69e+12
# windspeed:season[T.3]:numpy.power(windspeed, 2)                                                    2.194e+12   3.24e+12      0.677      0.506   -4.56e+12    8.95e+12
# windspeed:season[T.4]:numpy.power(windspeed, 2)                                                   -2.607e+11   1.39e+11     -1.879      0.075    -5.5e+11    2.86e+10
# temp:windspeed:numpy.power(windspeed, 2)                                                          -3.074e+11   8.71e+11     -0.353      0.728   -2.12e+12    1.51e+12
# temp:windspeed:season[T.2]:numpy.power(windspeed, 2)                                              -3.591e+12   2.44e+12     -1.473      0.156   -8.68e+12     1.5e+12
# temp:windspeed:season[T.3]:numpy.power(windspeed, 2)                                              -9.284e+12   1.36e+13     -0.680      0.504   -3.78e+13    1.92e+13
# temp:windspeed:season[T.4]:numpy.power(windspeed, 2)                                               1.962e+12   1.07e+12      1.836      0.081   -2.67e+11    4.19e+12
# hum:windspeed:numpy.power(windspeed, 2)                                                            -2.07e+11   6.24e+11     -0.332      0.744   -1.51e+12    1.09e+12
# hum:windspeed:season[T.2]:numpy.power(windspeed, 2)                                               -2.803e+12   1.88e+12     -1.493      0.151   -6.72e+12    1.11e+12
# hum:windspeed:season[T.3]:numpy.power(windspeed, 2)                                               -8.921e+12   1.49e+13     -0.597      0.557   -4.01e+13    2.22e+13
# hum:windspeed:season[T.4]:numpy.power(windspeed, 2)                                                1.363e+12   7.84e+11      1.738      0.098   -2.73e+11       3e+12
# temp:hum:windspeed:numpy.power(windspeed, 2)                                                       2.173e+12   5.78e+12      0.376      0.711   -9.88e+12    1.42e+13
# temp:hum:windspeed:season[T.2]:numpy.power(windspeed, 2)                                           1.391e+13   1.02e+13      1.358      0.190   -7.46e+12    3.53e+13
# temp:hum:windspeed:season[T.3]:numpy.power(windspeed, 2)                                            3.72e+13   6.21e+13      0.599      0.556   -9.23e+13    1.67e+14
# temp:hum:windspeed:season[T.4]:numpy.power(windspeed, 2)                                          -1.037e+13   6.51e+12     -1.593      0.127   -2.39e+13    3.21e+12
# numpy.power(temp, 2):numpy.power(windspeed, 2)                                                    -3.322e+11   6.99e+11     -0.475      0.640   -1.79e+12    1.13e+12
# season[T.2]:numpy.power(temp, 2):numpy.power(windspeed, 2)                                        -4.129e+12   2.65e+12     -1.558      0.135   -9.66e+12     1.4e+12
# season[T.3]:numpy.power(temp, 2):numpy.power(windspeed, 2)                                        -5.655e+12   1.01e+13     -0.562      0.580   -2.66e+13    1.53e+13
# season[T.4]:numpy.power(temp, 2):numpy.power(windspeed, 2)                                         2.242e+12   9.71e+11      2.308      0.032    2.15e+11    4.27e+12
# temp:numpy.power(temp, 2):numpy.power(windspeed, 2)                                                1.972e+11   4.16e+11      0.474      0.640    -6.7e+11    1.06e+12
# temp:season[T.2]:numpy.power(temp, 2):numpy.power(windspeed, 2)                                    2.459e+12   1.36e+12      1.810      0.085   -3.75e+11    5.29e+12
# temp:season[T.3]:numpy.power(temp, 2):numpy.power(windspeed, 2)                                    2.695e+12   5.41e+12      0.498      0.624   -8.59e+12     1.4e+13
# temp:season[T.4]:numpy.power(temp, 2):numpy.power(windspeed, 2)                                   -1.703e+12   6.63e+11     -2.567      0.018   -3.09e+12   -3.19e+11
# hum:numpy.power(temp, 2):numpy.power(windspeed, 2)                                                  3.37e+12   7.17e+12      0.470      0.643   -1.16e+13    1.83e+13
# hum:season[T.2]:numpy.power(temp, 2):numpy.power(windspeed, 2)                                     1.512e+13   1.17e+13      1.288      0.212   -9.36e+12    3.96e+13
# hum:season[T.3]:numpy.power(temp, 2):numpy.power(windspeed, 2)                                     2.059e+13   4.34e+13      0.474      0.641      -7e+13    1.11e+14
# hum:season[T.4]:numpy.power(temp, 2):numpy.power(windspeed, 2)                                    -1.238e+13   7.72e+12     -1.603      0.125   -2.85e+13    3.73e+12
# temp:hum:numpy.power(temp, 2):numpy.power(windspeed, 2)                                           -3.198e+12   3.97e+12     -0.807      0.429   -1.15e+13    5.07e+12
# temp:hum:season[T.2]:numpy.power(temp, 2):numpy.power(windspeed, 2)                               -7.873e+12   5.89e+12     -1.337      0.196   -2.02e+13    4.41e+12
# temp:hum:season[T.3]:numpy.power(temp, 2):numpy.power(windspeed, 2)                               -8.405e+12   2.08e+13     -0.404      0.691   -5.19e+13     3.5e+13
# temp:hum:season[T.4]:numpy.power(temp, 2):numpy.power(windspeed, 2)                                1.021e+13   4.46e+12      2.287      0.033    8.97e+11    1.95e+13
# windspeed:numpy.power(temp, 2):numpy.power(windspeed, 2)                                           7.857e+11   1.91e+12      0.412      0.685   -3.19e+12    4.77e+12
# windspeed:season[T.2]:numpy.power(temp, 2):numpy.power(windspeed, 2)                               6.152e+12   4.08e+12      1.508      0.147   -2.36e+12    1.47e+13
# windspeed:season[T.3]:numpy.power(temp, 2):numpy.power(windspeed, 2)                               1.302e+13   1.92e+13      0.679      0.505    -2.7e+13     5.3e+13
# windspeed:season[T.4]:numpy.power(temp, 2):numpy.power(windspeed, 2)                              -4.703e+12   2.34e+12     -2.007      0.058   -9.59e+12    1.86e+11
# temp:windspeed:numpy.power(temp, 2):numpy.power(windspeed, 2)                                     -5.833e+11   9.25e+11     -0.631      0.535   -2.51e+12    1.35e+12
# temp:windspeed:season[T.2]:numpy.power(temp, 2):numpy.power(windspeed, 2)                         -3.544e+12   2.03e+12     -1.749      0.096   -7.77e+12    6.82e+11
# temp:windspeed:season[T.3]:numpy.power(temp, 2):numpy.power(windspeed, 2)                         -6.055e+12   9.47e+12     -0.640      0.530   -2.58e+13    1.37e+13
# temp:windspeed:season[T.4]:numpy.power(temp, 2):numpy.power(windspeed, 2)                          3.606e+12   1.37e+12      2.640      0.016    7.57e+11    6.46e+12
# hum:windspeed:numpy.power(temp, 2):numpy.power(windspeed, 2)                                      -6.517e+12    1.5e+13     -0.434      0.669   -3.78e+13    2.48e+13
# hum:windspeed:season[T.2]:numpy.power(temp, 2):numpy.power(windspeed, 2)                          -2.224e+13   1.97e+13     -1.127      0.273   -6.34e+13    1.89e+13
# hum:windspeed:season[T.3]:numpy.power(temp, 2):numpy.power(windspeed, 2)                          -5.022e+13   8.38e+13     -0.599      0.556   -2.25e+14    1.25e+14
# hum:windspeed:season[T.4]:numpy.power(temp, 2):numpy.power(windspeed, 2)                           2.561e+13   1.63e+13      1.576      0.131   -8.29e+12    5.95e+13
# temp:hum:windspeed:numpy.power(temp, 2):numpy.power(windspeed, 2)                                  6.308e+12   1.08e+13      0.582      0.567   -1.63e+13    2.89e+13
# temp:hum:windspeed:season[T.2]:numpy.power(temp, 2):numpy.power(windspeed, 2)                      1.089e+13   1.23e+13      0.886      0.386   -1.48e+13    3.65e+13
# temp:hum:windspeed:season[T.3]:numpy.power(temp, 2):numpy.power(windspeed, 2)                      2.101e+13   3.73e+13      0.563      0.580   -5.69e+13    9.89e+13
# temp:hum:windspeed:season[T.4]:numpy.power(temp, 2):numpy.power(windspeed, 2)                     -2.085e+13   1.17e+13     -1.787      0.089   -4.52e+13    3.49e+12
# numpy.power(hum, 2):numpy.power(windspeed, 2)                                                     -2.587e+11      7e+11     -0.370      0.715   -1.72e+12     1.2e+12
# season[T.2]:numpy.power(hum, 2):numpy.power(windspeed, 2)                                         -2.397e+12   1.75e+12     -1.372      0.185   -6.04e+12    1.25e+12
# season[T.3]:numpy.power(hum, 2):numpy.power(windspeed, 2)                                         -4.681e+12   1.16e+13     -0.405      0.690   -2.88e+13    1.94e+13
# season[T.4]:numpy.power(hum, 2):numpy.power(windspeed, 2)                                          1.095e+12   7.79e+11      1.406      0.175   -5.29e+11    2.72e+12
# temp:numpy.power(hum, 2):numpy.power(windspeed, 2)                                                 2.757e+12   6.62e+12      0.416      0.682   -1.11e+13    1.66e+13
# temp:season[T.2]:numpy.power(hum, 2):numpy.power(windspeed, 2)                                     1.144e+13   9.96e+12      1.149      0.264   -9.34e+12    3.22e+13
# temp:season[T.3]:numpy.power(hum, 2):numpy.power(windspeed, 2)                                     1.866e+13   4.71e+13      0.396      0.696   -7.97e+13    1.17e+14
# temp:season[T.4]:numpy.power(hum, 2):numpy.power(windspeed, 2)                                    -8.783e+12   6.94e+12     -1.266      0.220   -2.33e+13    5.69e+12
# hum:numpy.power(hum, 2):numpy.power(windspeed, 2)                                                  1.776e+11   4.41e+11      0.403      0.691   -7.41e+11     1.1e+12
# hum:season[T.2]:numpy.power(hum, 2):numpy.power(windspeed, 2)                                       1.03e+12      8e+11      1.287      0.213   -6.39e+11     2.7e+12
# hum:season[T.3]:numpy.power(hum, 2):numpy.power(windspeed, 2)                                      1.912e+12    5.8e+12      0.330      0.745   -1.02e+13     1.4e+13
# hum:season[T.4]:numpy.power(hum, 2):numpy.power(windspeed, 2)                                     -6.344e+11   4.79e+11     -1.326      0.200   -1.63e+12    3.64e+11
# temp:hum:numpy.power(hum, 2):numpy.power(windspeed, 2)                                             -1.98e+12   4.37e+12     -0.454      0.655   -1.11e+13    7.13e+12
# temp:hum:season[T.2]:numpy.power(hum, 2):numpy.power(windspeed, 2)                                -4.516e+12    5.3e+12     -0.852      0.404   -1.56e+13    6.54e+12
# temp:hum:season[T.3]:numpy.power(hum, 2):numpy.power(windspeed, 2)                                -7.088e+12   2.31e+13     -0.306      0.763   -5.54e+13    4.12e+13
# temp:hum:season[T.4]:numpy.power(hum, 2):numpy.power(windspeed, 2)                                 5.212e+12    4.5e+12      1.159      0.260   -4.17e+12    1.46e+13
# windspeed:numpy.power(hum, 2):numpy.power(windspeed, 2)                                            4.328e+11   1.21e+12      0.359      0.724   -2.08e+12    2.95e+12
# windspeed:season[T.2]:numpy.power(hum, 2):numpy.power(windspeed, 2)                                3.679e+12   2.52e+12      1.458      0.160   -1.58e+12    8.94e+12
# windspeed:season[T.3]:numpy.power(hum, 2):numpy.power(windspeed, 2)                                1.175e+13   2.27e+13      0.518      0.610   -3.56e+13    5.91e+13
# windspeed:season[T.4]:numpy.power(hum, 2):numpy.power(windspeed, 2)                               -2.372e+12   1.45e+12     -1.639      0.117   -5.39e+12    6.48e+11
# temp:windspeed:numpy.power(hum, 2):numpy.power(windspeed, 2)                                      -4.774e+12   1.17e+13     -0.407      0.689   -2.93e+13    1.97e+13
# temp:windspeed:season[T.2]:numpy.power(hum, 2):numpy.power(windspeed, 2)                           -1.73e+13   1.56e+13     -1.110      0.280   -4.98e+13    1.52e+13
# temp:windspeed:season[T.3]:numpy.power(hum, 2):numpy.power(windspeed, 2)                           -4.78e+13   9.29e+13     -0.515      0.612   -2.42e+14    1.46e+14
# temp:windspeed:season[T.4]:numpy.power(hum, 2):numpy.power(windspeed, 2)                            1.83e+13   1.27e+13      1.440      0.165   -8.21e+12    4.48e+13
# hum:windspeed:numpy.power(hum, 2):numpy.power(windspeed, 2)                                       -2.875e+11   7.35e+11     -0.391      0.700   -1.82e+12    1.25e+12
# hum:windspeed:season[T.2]:numpy.power(hum, 2):numpy.power(windspeed, 2)                           -1.583e+12   1.18e+12     -1.338      0.196   -4.05e+12    8.85e+11
# hum:windspeed:season[T.3]:numpy.power(hum, 2):numpy.power(windspeed, 2)                           -5.049e+12   1.14e+13     -0.445      0.661   -2.87e+13    1.86e+13
# hum:windspeed:season[T.4]:numpy.power(hum, 2):numpy.power(windspeed, 2)                            1.371e+12   8.62e+11      1.590      0.128   -4.28e+11    3.17e+12
# temp:hum:windspeed:numpy.power(hum, 2):numpy.power(windspeed, 2)                                   3.285e+12   7.38e+12      0.445      0.661   -1.21e+13    1.87e+13
# temp:hum:windspeed:season[T.2]:numpy.power(hum, 2):numpy.power(windspeed, 2)                       6.817e+12   8.48e+12      0.804      0.431   -1.09e+13    2.45e+13
# temp:hum:windspeed:season[T.3]:numpy.power(hum, 2):numpy.power(windspeed, 2)                       1.976e+13   4.58e+13      0.431      0.671   -7.58e+13    1.15e+14
# temp:hum:windspeed:season[T.4]:numpy.power(hum, 2):numpy.power(windspeed, 2)                      -1.073e+13   7.85e+12     -1.367      0.187   -2.71e+13    5.65e+12
# numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)                                 -8.91e+12   1.81e+13     -0.492      0.628   -4.67e+13    2.88e+13
# season[T.2]:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)                     -1.66e+13   2.11e+13     -0.789      0.440   -6.05e+13    2.73e+13
# season[T.3]:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)                    -2.215e+13   6.07e+13     -0.365      0.719   -1.49e+14    1.04e+14
# season[T.4]:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)                     2.313e+13   1.85e+13      1.248      0.227   -1.55e+13    6.18e+13
# temp:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)                            9.764e+12   1.46e+13      0.668      0.511   -2.07e+13    4.02e+13
# temp:season[T.2]:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)                5.624e+12   1.52e+13      0.370      0.716   -2.61e+13    3.74e+13
# temp:season[T.3]:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)                5.315e+12   2.43e+13      0.219      0.829   -4.54e+13     5.6e+13
# temp:season[T.4]:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)               -2.068e+13   1.48e+13     -1.396      0.178   -5.16e+13    1.02e+13
# hum:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)                             6.877e+12    1.3e+13      0.529      0.602   -2.02e+13     3.4e+13
# hum:season[T.2]:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)                 4.879e+12   1.36e+13      0.359      0.723   -2.35e+13    3.32e+13
# hum:season[T.3]:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)                 6.305e+12   2.76e+13      0.229      0.821   -5.12e+13    6.38e+13
# hum:season[T.4]:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)                -1.438e+13   1.31e+13     -1.096      0.286   -4.18e+13     1.3e+13
# temp:hum:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)                       -8.106e+12   1.22e+13     -0.665      0.514   -3.35e+13    1.73e+13
# temp:hum:season[T.2]:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)            9.582e+11   1.22e+13      0.078      0.938   -2.45e+13    2.65e+13
# temp:hum:season[T.3]:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)            1.687e+12   8.54e+12      0.198      0.845   -1.61e+13    1.95e+13
# temp:hum:season[T.4]:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)             1.38e+13   1.22e+13      1.129      0.272   -1.17e+13    3.93e+13
# windspeed:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)                       1.573e+13   3.35e+13      0.469      0.644   -5.41e+13    8.56e+13
# windspeed:season[T.2]:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)           2.397e+13   3.65e+13      0.656      0.519   -5.22e+13       1e+14
# windspeed:season[T.3]:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)           6.012e+13   1.19e+14      0.504      0.620   -1.89e+14    3.09e+14
# windspeed:season[T.4]:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)          -4.679e+13   3.49e+13     -1.342      0.194   -1.19e+14    2.59e+13
# temp:windspeed:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)                 -1.715e+13   2.91e+13     -0.589      0.562   -7.79e+13    4.36e+13
# temp:windspeed:season[T.2]:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)     -6.745e+12   2.96e+13     -0.228      0.822   -6.84e+13    5.49e+13
# temp:windspeed:season[T.3]:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)     -1.943e+13   4.57e+13     -0.425      0.675   -1.15e+14    7.59e+13
# temp:windspeed:season[T.4]:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)      4.051e+13   2.97e+13      1.362      0.188   -2.15e+13    1.03e+14
# hum:windspeed:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)                   -1.15e+13   2.23e+13     -0.516      0.612    -5.8e+13     3.5e+13
# hum:windspeed:season[T.2]:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)      -6.789e+12    2.3e+13     -0.295      0.771   -5.47e+13    4.12e+13
# hum:windspeed:season[T.3]:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)      -2.178e+13   5.58e+13     -0.391      0.700   -1.38e+14    9.46e+13
# hum:windspeed:season[T.4]:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)       2.838e+13   2.29e+13      1.241      0.229   -1.93e+13    7.61e+13
# temp:hum:windspeed:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)              1.345e+13   2.14e+13      0.629      0.536   -3.11e+13     5.8e+13
# temp:hum:windspeed:season[T.2]:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)  -2.35e+12   2.14e+13     -0.110      0.914   -4.69e+13    4.22e+13
# temp:hum:windspeed:season[T.3]:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2)   2.64e+12   1.74e+13      0.151      0.881   -3.37e+13     3.9e+13
# temp:hum:windspeed:season[T.4]:numpy.power(temp, 2):numpy.power(hum, 2):numpy.power(windspeed, 2) -2.599e+13   2.15e+13     -1.207      0.242   -7.09e+13    1.89e+13
# ==============================================================================
# Omnibus:                       58.747   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              973.765
# Skew:                          -0.167   Prob(JB):                    3.54e-212
# Kurtosis:                      12.246   Cond. No.                     1.27e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.37e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# In this case we end up with a model that fits the training data almost perfectly, and fails totally on the testing data. This is a classic case of overfitting, and is something that can easily happen if we aren't careful and make our model too complex.
#
# We can see in this case also, our qqplot looks pretty awful which is also a good sign something has gone wrong.

# %% [markdown]
# ## Final Thoughts and Other Things
#
# This example has looked at regression, and assessing model validity. There are few things to condiser when analysing a model, in no particular order these are:
# * Is the model any good? $R^2$ and RMSE can help here
# * Are all the terms important? p-values are your friend in this case, though be aware that there are issues with p-values, and in some contexts these are no longer widely used as the can be misused.
# * If you need to remove terms because they have a poor p-value, it's important to check why this p-value is bad. Is it because the predictor and response are not related, or is it becuase the predictor is correlated with other predictors? Check the cross correlation between predictors to make sure that you're not accidently removing a useful term.
# * The distribution of the residuals. These should be normally distributed, if they're not, then you're model is not valid, and may result in the some weird predictions. In practice, while we aim for normally distributed residuals, you will very rarely get results that fit the normal curve exceptionally well. If you consider what we've seen above, most of our models except for the final one (with the quadratic terms) were fairly good, and only our last one had any major problems in terms of the distribution of the residuals.
# * Categorical values can be incorporated into models, but need to be captured differently. These don't add a slope so much as a series of offsets for each category
# * We can add higher order terms that capture more complex relationships in the data. This can greatly aid performance, but also expose us to the risk of overfitting.
